# %%
import torch
import numpy as np
import SpectralSynthesis as SS
import matplotlib.pyplot as plt

# %%
field_3D = SS.fBm(N=500, H = 0.5, E=3, exp=True, sigma = 1)

plt.figure(figsize = (12,12))
plt.imshow(field_3D[:,:,0])
# Out:
# C:\Users\C1764397\Workshop\PhD\Scripts\SpectralSynthesis.py:58: RuntimeWarning: divide by zero encountered in power
#   rad = np.where(k>0.0,k**(-(beta*0.5)),0.0)

# %%
field_tensor = torch.tensor(field_3D)

# %%
field_tensor.shape
# Out:
# torch.Size([500, 500, 500])

# %%
plt.figure(figsize=(12,12))
plt.imshow(field_tensor[:,:,10])

# %%
np.savetxt('3D Cloud.txt',field_3D)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-402d73ec11ed> in <module>()
# ----> 1 np.savetxt('3D Cloud.txt',field_3D)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1323         if X.ndim == 0 or X.ndim > 2:
#    1324             raise ValueError(
# -> 1325                 "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1326         elif X.ndim == 1:
#    1327             # Common case -- 1d array of numbers
#
# ValueError: Expected 1D or 2D array, got 3D array instead
