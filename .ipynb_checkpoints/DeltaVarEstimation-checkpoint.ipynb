# %%
import numpy as np
import matplotlib.pyplot as plt
import SpectralSynthesis as SS
import DeltaVar as DV

# %%
X1 = SS.fBm(1000,2,0.0,exp = True)
X2 = SS.fBm(1000,2,0.5,exp = True)
X3 = SS.fBm(1000,2,1.0,exp = True)
# Out:
# C:\Users\C1764397\Workshop\PhD\Scripts\SpectralSynthesis.py:57: RuntimeWarning: divide by zero encountered in reciprocal
#   rad = np.where(k>0.0,k**(-(beta*0.5)),0.0)
# C:\Users\C1764397\Workshop\PhD\Scripts\SpectralSynthesis.py:57: RuntimeWarning: divide by zero encountered in power
#   rad = np.where(k>0.0,k**(-(beta*0.5)),0.0)

# %%
plt.imshow(X1, origin = 'lower')
plt.colorbar()
plt.show()

# %%
plt.imshow(X2, origin = 'lower')
plt.colorbar()
plt.show()

# %%
plt.imshow(X3, origin = 'lower')
plt.colorbar()
plt.show()

# %%
L = 10**(np.linspace(np.log10(0.003),np.log10(0.1), 100))
v = 1.5

# %%
sigma_d = []
for i in range(len(L)):
    sigma_d.append(DV.DeltaVar(X1,L[i],v, method = 'convolve'))
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-61d0457011df> in <module>()
#       1 sigma_d = []
#       2 for i in range(len(L)):
# ----> 3     sigma_d.append(DV.DeltaVar(X1,L[i],v, method = 'convolve'))
#       4     print(i)
#
# ~\Workshop\PhD\Scripts\DeltaVar.py in DeltaVar(X, L, v, method)
#      30         f = MexicanHat(r,L,v)
#      31
# ---> 32         g = convolve(X,f, normalize_kernel = False, nan_treatment = 'fill')
#      33
#      34         deltavar = np.mean(np.power(g,2), dtype=np.float64)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\astropy\utils\decorators.py in wrapper(*args, **kwargs)
#     505                         # one with the name of the new argument to the function
#     506                         kwargs[new_name[i]] = value
# --> 507             return function(*args, **kwargs)
#     508
#     509         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\astropy\utils\decorators.py in convolve_fft(array, kernel, boundary, fill_value, nan_treatment, normalize_kernel, normalization_zero_tol, preserve_nan, mask, crop, return_fft, fft_pad, psf_pad, quiet, min_wt, allow_huge, fftn, ifftn, complex_dtype)
#     866             name = func.__name__
#     867
# --> 868         func = make_function_with_signature(func, name=name, **wrapped_args)
#     869         func = functools.update_wrapper(func, wrapped, assigned=assigned,
#     870                                         updated=updated)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\astropy\nddata\decorators.py in wrapper(data, *args, **kwargs)
#     247                                   AstropyUserWarning)
#     248
# --> 249             result = func(data, *args, **kwargs)
#     250
#     251             if unpack and repack:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\astropy\convolution\convolve.py in convolve_fft(array, kernel, boundary, fill_value, nan_treatment, normalize_kernel, normalization_zero_tol, preserve_nan, mask, crop, return_fft, fft_pad, psf_pad, quiet, min_wt, allow_huge, fftn, ifftn, complex_dtype)
#     641         raise ValueError("Size Error: Arrays will be {}.  Use "
#     642                          "allow_huge=True to override this exception."
# --> 643                          .format(human_file_size(array_size_C)))
#     644
#     645     # For future reference, this can be used to predict "almost exactly"
#
# ValueError: Size Error: Arrays will be 1.0G.  Use allow_huge=True to override this exception.

# %%
sigma_d1 = sigma_d

# %%
sigma_d2 = []
for i in range(len(L)):
    sigma_d2.append(DV.DeltaVar(X2,L[i],v, method = 'convolve'))
    print(i)

# %%
sigma_d3 = []
for i in range(len(L)):
    sigma_d3.append(DV.DeltaVar(X3,L[i],v, method = 'convolve'))
    print(i)

# %%
plt.plot(np.log10(L),np.log10(sigma_d1))
plt.plot(np.log10(L),np.log10(sigma_d2))
plt.plot(np.log10(L),np.log10(sigma_d3))
plt.grid()
plt.show()
