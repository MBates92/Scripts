# %%
import numpy as np
import matplotlib.pyplot as plt
import SpectralSynthesis as ss

# %%
H_min = 0.0
H_max = 1.0

sigma_min = 0.1
sigma_max = 3.0

# %%
N = 20000

H_list = np.random.random(N)
sigma_list = (sigma_max-sigma_min)*np.random.random(N)+sigma_min

plt.figure()
plt.hist(H_list,bins = 10)

plt.figure()
plt.hist(sigma_list, bins=10)
# Out:
# (array([ 1908.,  1937.,  2029.,  1947.,  2031.,  2084.,  2007.,  1981.,
#          2047.,  2029.]),
#  array([ 0.10011283,  0.39009502,  0.68007722,  0.97005942,  1.26004162,
#          1.55002382,  1.84000601,  2.12998821,  2.41997041,  2.70995261,
#          2.9999348 ]),
#  <a list of 10 Patch objects>)

# %%
target_list = []
target_list.append(H_list)
target_list.append(sigma_list)
print(target_list)
# Out:
# [array([ 0.63333986,  0.27407292,  0.77559616, ...,  0.9681975 ,
#         0.78999605,  0.90658977]), array([ 1.49330252,  0.14719329,  1.16495066, ...,  1.49973599,
#         1.30661061,  1.01897898])]

# %%
plt.figure()
plt.hist(target_list[0],bins = 10)

plt.figure()
plt.hist(target_list[1], bins=10)
# Out:
# (array([ 1908.,  1937.,  2029.,  1947.,  2031.,  2084.,  2007.,  1981.,
#          2047.,  2029.]),
#  array([ 0.10011283,  0.39009502,  0.68007722,  0.97005942,  1.26004162,
#          1.55002382,  1.84000601,  2.12998821,  2.41997041,  2.70995261,
#          2.9999348 ]),
#  <a list of 10 Patch objects>)

# %%
N_p = 100
E = 2

# %%
path = '../Data/fBmFields/2DExponentiated/100px/Training/features/'
for i in range(N):
    field = ss.fBm(N_p,E,H=target_list[0][i],sigma=target_list[1][i])
    field = field-np.amin(field)
    field /= np.amax(field)
    np.savetxt('{}field_{num:06d}.txt'.format(path,num=i),field)
# Out:
# C:\Users\C1764397\Workshop\PhD\Scripts\SpectralSynthesis.py:58: RuntimeWarning: divide by zero encountered in power
#   rad = np.where(k>0.0,k**(-(beta*0.5)),0.0)

# %%
path = '../Data/fBmFields/2DExponentiated/100px/Training/labels/'
np.savetxt('{}labels.txt'.format(path),np.asarray(target_list).T)
